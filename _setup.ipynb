# %% [markdown]
# ## Mapping ordinal features

# %%
ORDINAL_COLUMNS = ['EdLevel', 'Age1stCode', 'OrgSize', 'Age']

# %%
ed_level_mapping = {
    "Primary/elementary school": 1.0,
    "Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)": 2.0,
    "Associate degree (A.A., A.S., etc.)": 3.0,
    "Some college/university study without earning a degree": 4.0,
    "Something else, Professional degree (JD, MD, etc.)": 5.0,
    "Bachelor’s degree (B.A., B.S., B.Eng., etc.)": 6.0,
    "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)": 7.0,
    "Other doctoral degree (Ph.D., Ed.D., etc.)": 8.0,
}

# %%
age_fst_code_mapping = {
    "Younger than 5 years": 1.0,
    "5 - 10 years": 2.0,
    "11 - 17 years": 3.0,
    "18 - 24 years": 4.0,
    "25 - 34 years": 5.0,
    "35 - 44 years": 6.0,
    "45 - 54 years": 7.0,
    "55 - 64 years": 8.0,
    "Older than 64 years": 9.0,
}

# %%
org_size_mapping = {
    "Just me - I am a freelancer, sole proprietor, etc.": 1.0,
    "2 to 9 employees": 2.0,
    "10 to 19 employees": 3.0,
    "20 to 99 employees": 4.0,
    "100 to 499 employees": 5.0,
    "I don’t know": 6.0,
    "500 to 999 employees": 7.0,
    "1,000 to 4,999 employees": 8.0,
    "5,000 to 9,999 employees": 9.0,
    "10,000 or more employees": 10.0,
}

# %%
age_mapping = {
    "Under 18 years old": 1.0,
    "18-24 years old": 2.0,
    "25-34 years old": 3.0,
    "35-44 years old": 4.0,
    "45-54 years old": 5.0,
    "55-64 years old": 6.0,
    "65 years or older": 7.0,
    "Prefer not to say": 8.0,
}

# %%
ORDINAL_MAPPING = {
    "EdLevel": ed_level_mapping,
    "Age1stCode": age_fst_code_mapping,
    "OrgSize": org_size_mapping,
    "Age": age_mapping,
}

# %%
ORDINAL_MAPPING
# Out:
# Out[39]: {'EdLevel': {'Primary/elementary school': 1.0,
#   'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)': 2.0,
#   'Associate degree (A.A., A.S., etc.)': 3.0,
#   'Some college/university study without earning a degree': 4.0,
#   'Something else, Professional degree (JD, MD, etc.)': 5.0,
#   'Bachelor’s degree (B.A., B.S., B.Eng., etc.)': 6.0,
#   'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)': 7.0,
#   'Other doctoral degree (Ph.D., Ed.D., etc.)': 8.0},
#  'Age1stCode': {'Younger than 5 years': 1.0,
#   '5 - 10 years': 2.0,
#   '11 - 17 years': 3.0,
#   '18 - 24 years': 4.0,
#   '25 - 34 years': 5.0,
#   '35 - 44 years': 6.0,
#   '45 - 54 years': 7.0,
#   '55 - 64 years': 8.0,
#   'Older than 64 years': 9.0},
#  'OrgSize': {'Just me - I am a freelancer, sole proprietor, etc.': 1.0,
#   '2 to 9 employees': 2.0,
#   '10 to 19 employees': 3.0,
#   '20 to 99 employees': 4.0,
#   '100 to 499 employees': 5.0,
#   'I don’t know': 6.0,
#   '500 to 999 employees': 7.0,
#   '1,000 to 4,999 employees': 8.0,
#   '5,000 to 9,999 employees': 9.0,
#   '10,000 or more employees': 10.0},
#  'Age': {'Under 18 years old': 1.0,
#   '18-24 years old': 2.0,
#   '25-34 years old': 3.0,
#   '35-44 years old': 4.0,
#   '45-54 years old': 5.0,
#   '55-64 years old': 6.0,
#   '65 years or older': 7.0,
#   'Prefer not to say': 8.0},
#  'YearsCode_bin': {'0 - 3': 1.0,
#   '3 - 5': 2.0,
#   '5 - 10': 3.0,
#   '10 - 20': 4.0,
#   '20 - 30': 5.0,
#   '30 - 40': 6.0,
#   '40 - 50': 7.0,
#   '50 - 60': 8.0},
#  'YearsCodePro_bin': {'0 - 3': 1.0,
#   '3 - 5': 2.0,
#   '5 - 10': 3.0,
#   '10 - 20': 4.0,
#   '20 - 30': 5.0,
#   '30 - 40': 6.0,
#   '40 - 50': 7.0,
#   '50 - 60': 8.0}}
